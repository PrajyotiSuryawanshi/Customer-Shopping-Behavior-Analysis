# %%
import pandas as pd

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("customer_shopping_behavior.csv")

# %%
df.head()
# Out:
#    Customer ID  Age  Gender Item Purchased  Category  Purchase Amount (USD)  \
# 0            1   63  Female         Shorts  Clothing                     31
# 1            2   39    Male        Sandals  Footwear                     85
# 2            3   40  Female         Hoodie  Clothing                     72
# 3            4   47    Male          Pants  Clothing                     55
# 4            5   22    Male          Dress  Clothing                     36
#
#    Location Size  Color  Season  Review Rating Subscription Status  \
# 0  New York   XL   Blue  Summer           3.62                 Yes
# 1   Arizona   XL    Red    Fall           3.53                 Yes
# 2   Florida    L  White  Summer           3.61                  No
# 3  New York   XL   Pink  Winter           4.31                  No
# 4  New York    L  Black  Summer           4.72                 Yes
#
#     Shipping Type Discount Applied Promo Code Used  Previous Purchases  \
# 0   Free Shipping               No              No                  36
# 1         Express              Yes             Yes                  12
# 2    Store Pickup               No              No                  50
# 3  2-Day Shipping               No              No                  40
# 4         Express               No              No                  12
#
#   Payment Method Frequency of Purchases
# 0  Bank Transfer               Annually
# 1     Debit Card              Quarterly
# 2          Venmo                Monthly
# 3         PayPal                Monthly
# 4          Venmo                Monthly

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 3900 entries, 0 to 3899
# Data columns (total 18 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Customer ID             3900 non-null   int64
#  1   Age                     3900 non-null   int64
#  2   Gender                  3900 non-null   str
#  3   Item Purchased          3900 non-null   str
#  4   Category                3900 non-null   str
#  5   Purchase Amount (USD)   3900 non-null   int64
#  6   Location                3900 non-null   str
#  7   Size                    3900 non-null   str
#  8   Color                   3900 non-null   str
#  9   Season                  3900 non-null   str
#  10  Review Rating           3850 non-null   float64
#  11  Subscription Status     3900 non-null   str
#  12  Shipping Type           3900 non-null   str
#  13  Discount Applied        3900 non-null   str
#  14  Promo Code Used         3900 non-null   str
#  15  Previous Purchases      3900 non-null   int64
#  16  Payment Method          3900 non-null   str
#  17  Frequency of Purchases  3900 non-null   str
# dtypes: float64(1), int64(4), str(13)
# memory usage: 548.6 KB

# %%
df.describe(include='all')
# Out:
#         Customer ID          Age  Gender Item Purchased  Category  \
# count   3900.000000  3900.000000    3900           3900      3900
# unique          NaN          NaN       2             15         2
# top             NaN          NaN  Female         Blouse  Clothing
# freq            NaN          NaN    1978            280      3105
# mean    1950.500000    43.525897     NaN            NaN       NaN
# std     1125.977353    15.091466     NaN            NaN       NaN
# min        1.000000    18.000000     NaN            NaN       NaN
# 25%      975.750000    30.000000     NaN            NaN       NaN
# 50%     1950.500000    43.000000     NaN            NaN       NaN
# 75%     2925.250000    56.000000     NaN            NaN       NaN
# max     3900.000000    70.000000     NaN            NaN       NaN
#
#         Purchase Amount (USD)  Location  Size Color  Season  Review Rating  \
# count             3900.000000      3900  3900  3900    3900    3850.000000
# unique                    NaN        15     4    10       4            NaN
# top                       NaN  Colorado     M   Red  Spring            NaN
# freq                      NaN       275  1029   418    1085            NaN
# mean                59.528718       NaN   NaN   NaN     NaN       3.806055
# std                 23.376079       NaN   NaN   NaN     NaN       0.588046
# min                 20.000000       NaN   NaN   NaN     NaN       2.030000
# 25%                 39.000000       NaN   NaN   NaN     NaN       3.400000
# 50%                 60.000000       NaN   NaN   NaN     NaN       3.800000
# 75%                 80.000000       NaN   NaN   NaN     NaN       4.220000
# max                100.000000       NaN   NaN   NaN     NaN       5.000000
#
#        Subscription Status Shipping Type Discount Applied Promo Code Used  \
# count                 3900          3900             3900            3900
# unique                   2             6                2               2
# top                     No      Standard               No              No
# freq                  2833           700             2188            2188
# mean                   NaN           NaN              NaN             NaN
# std                    NaN           NaN              NaN             NaN
# min                    NaN           NaN              NaN             NaN
# 25%                    NaN           NaN              NaN             NaN
# 50%                    NaN           NaN              NaN             NaN
# 75%                    NaN           NaN              NaN             NaN
# max                    NaN           NaN              NaN             NaN
#
#         Previous Purchases Payment Method Frequency of Purchases
# count          3900.000000           3900                   3900
# unique                 NaN              6                      7
# top                    NaN         PayPal                Monthly
# freq                   NaN            683                    589
# mean             25.549231            NaN                    NaN
# std              14.427428            NaN                    NaN
# min               1.000000            NaN                    NaN
# 25%              13.000000            NaN                    NaN
# 50%              26.000000            NaN                    NaN
# 75%              38.000000            NaN                    NaN
# max              50.000000            NaN                    NaN

# %%
df.isnull().sum()
# Out:
# Customer ID                0
# Age                        0
# Gender                     0
# Item Purchased             0
# Category                   0
# Purchase Amount (USD)      0
# Location                   0
# Size                       0
# Color                      0
# Season                     0
# Review Rating             50
# Subscription Status        0
# Shipping Type              0
# Discount Applied           0
# Promo Code Used            0
# Previous Purchases         0
# Payment Method             0
# Frequency of Purchases     0
# dtype: int64

# %%
df = pd.read_csv("customer_shopping_behavior.csv")

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='str')

# %%
df['Review Rating'] = df.groupby('Category')['Review Rating'].transform(
    lambda x: x.fillna(x.median())
)

# %%
df['Review Rating'].isnull().sum()
# Out:
# np.int64(0)

# %%
df.columns
# Out:
# Index(['Customer ID', 'Age', 'Gender', 'Item Purchased', 'Category',
#        'Purchase Amount (USD)', 'Location', 'Size', 'Color', 'Season',
#        'Review Rating', 'Subscription Status', 'Shipping Type',
#        'Discount Applied', 'Promo Code Used', 'Previous Purchases',
#        'Payment Method', 'Frequency of Purchases'],
#       dtype='str')

# %%
df.columns = df.columns.str.lower()
df.columns = df.columns.str.replace(' ', '_')
df = df.rename(columns={'purchase_amount_(usd)':'purchase_amount'})

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'promo_code_used', 'previous_purchases',
#        'payment_method', 'frequency_of_purchases'],
#       dtype='str')

# %%
labels = ['Young Adult','Adult','Middle-aged','Senior']
df['age_group']= pd.qcut(df['age'],q=4,labels=labels)

# %%
df[['age','age_group']].head(10)
# Out:
#    age    age_group
# 0   63       Senior
# 1   39        Adult
# 2   40        Adult
# 3   47  Middle-aged
# 4   22  Young Adult
# 5   26  Young Adult
# 6   38        Adult
# 7   28  Young Adult
# 8   22  Young Adult
# 9   52  Middle-aged

# %%
df.columns.tolist()
# Out:
# ['customer_id',
#  'age',
#  'gender',
#  'item_purchased',
#  'category',
#  'purchase_amount',
#  'location',
#  'size',
#  'color',
#  'season',
#  'review_rating',
#  'subscription_status',
#  'shipping_type',
#  'discount_applied',
#  'promo_code_used',
#  'previous_purchases',
#  'payment_method',
#  'frequency_of_purchases',
#  'age_group']

# %%
frequency_mapping = {
    'Fortnightly': 14,
    'Weekly': 7,
    'Monthly': 30,
    'Quarterly': 90,
    'Bi-Weekly': 14,
    'Annually': 365,
    'Every 3 Months': 90
}

df['purchase_frequency_days'] = df['frequency_of_purchases'].map(frequency_mapping)

# %%
df[['frequency_of_purchases', 'purchase_frequency_days']].head(10)
# Out:
#   frequency_of_purchases  purchase_frequency_days
# 0               Annually                      365
# 1              Quarterly                       90
# 2                Monthly                       30
# 3                Monthly                       30
# 4                Monthly                       30
# 5                Monthly                       30
# 6                Monthly                       30
# 7               Annually                      365
# 8              Bi-Weekly                       14
# 9         Every 3 Months                       90

# %%
df[['discount_applied','promo_code_used']].head(10)
# Out:
#   discount_applied promo_code_used
# 0               No              No
# 1              Yes             Yes
# 2               No              No
# 3               No              No
# 4               No              No
# 5              Yes             Yes
# 6               No              No
# 7               No              No
# 8               No              No
# 9              Yes             Yes

# %%
(df['discount_applied']==df['promo_code_used']).all()
# Out:
# np.True_

# %%
df=df.drop('promo_code_used',axis=1)

# %%
df.columns
# Out:
# Index(['customer_id', 'age', 'gender', 'item_purchased', 'category',
#        'purchase_amount', 'location', 'size', 'color', 'season',
#        'review_rating', 'subscription_status', 'shipping_type',
#        'discount_applied', 'previous_purchases', 'payment_method',
#        'frequency_of_purchases', 'age_group', 'purchase_frequency_days'],
#       dtype='str')

# %%
import pymysql

# %%
from sqlalchemy import create_engine

# %%
engine = create_engine(
    "mysql+pymysql://root:12345@localhost/customer_shopping_db"
)

# %%
with engine.connect() as conn:
    print("MySQL Connected Successfully!")
# Out:
# MySQL Connected Successfully!

# %%
df.to_sql(
    name='customer_shopping',
    con=engine,
    if_exists='replace',
    index=False
)
# Out:
# 3900

# %%
print("Data uploaded to MySQL successfully!")
# Out:
# Data uploaded to MySQL successfully!
